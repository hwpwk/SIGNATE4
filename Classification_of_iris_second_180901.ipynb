# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.linear_model import LinearRegression as LR
from sklearn.ensemble import RandomForestClassifier

# %%
df_train = pd.read_csv('train.csv', sep='\t')
df_test = pd.read_csv('test.csv', sep='\t')

# %%
df_train.head()
# Out:
#    id  sepal length in cm  sepal width in cm  petal length in cm  \
# 0   0                 5.3                3.7                 1.5
# 1   1                 6.8                2.8                 4.8
# 2   3                 6.1                3.0                 4.9
# 3   4                 6.4                3.2                 5.3
# 4   5                 6.3                3.3                 4.7
#
#    petal width in cm            class
# 0                0.2      Iris-setosa
# 1                1.4  Iris-versicolor
# 2                1.8   Iris-virginica
# 3                2.3   Iris-virginica
# 4                1.6  Iris-versicolor

# %%
df_test.head()
# Out:
#    id  sepal length in cm  sepal width in cm  petal length in cm  \
# 0   2                 6.1                2.8                 4.7
# 1   7                 6.3                2.5                 4.9
# 2   8                 6.2                3.4                 5.4
# 3  10                 6.7                3.1                 4.7
# 4  13                 5.0                3.4                 1.6
#
#    petal width in cm
# 0                1.2
# 1                1.5
# 2                2.3
# 3                1.5
# 4                0.4

# %%
print(df_train.info())
print(df_train.isnull().sum())
print(df_test.info())
print(df_test.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 6 columns):
# id                    75 non-null int64
# sepal length in cm    75 non-null float64
# sepal width in cm     75 non-null float64
# petal length in cm    75 non-null float64
# petal width in cm     75 non-null float64
# class                 75 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 3.6+ KB
# None
# id                    0
# sepal length in cm    0
# sepal width in cm     0
# petal length in cm    0
# petal width in cm     0
# class                 0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 5 columns):
# id                    75 non-null int64
# sepal length in cm    75 non-null float64
# sepal width in cm     75 non-null float64
# petal length in cm    75 non-null float64
# petal width in cm     75 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 3.0 KB
# None
# id                    0
# sepal length in cm    0
# sepal width in cm     0
# petal length in cm    0
# petal width in cm     0
# dtype: int64

# %%
# train,testのうちtrainの[classカラム]以外すべて数値型、欠損値無し

# %%
# classカラムを数値型に変更したい
# まずはclassカラムに何種類のアヤメがあるのかを確認
df_train['class'].value_counts()
# Out:
# Iris-virginica     29
# Iris-setosa        25
# Iris-versicolor    21
# Name: class, dtype: int64

# %%
# 3種類なので0,1,2に分類する
df_train2 = df_train.replace('Iris-virginica', 0).replace('Iris-setosa', 1).replace('Iris-versicolor', 2)

# %%
df_train2.head()
# Out:
#    id  sepal length in cm  sepal width in cm  petal length in cm  \
# 0   0                 5.3                3.7                 1.5
# 1   1                 6.8                2.8                 4.8
# 2   3                 6.1                3.0                 4.9
# 3   4                 6.4                3.2                 5.3
# 4   5                 6.3                3.3                 4.7
#
#    petal width in cm  class
# 0                0.2      1
# 1                1.4      2
# 2                1.8      0
# 3                2.3      0
# 4                1.6      2

# %%
df_train2.corr()
# Out:
#                           id  sepal length in cm  sepal width in cm  \
# id                  1.000000           -0.153779           0.018168
# sepal length in cm -0.153779            1.000000          -0.150560
# sepal width in cm   0.018168           -0.150560           1.000000
# petal length in cm -0.146934            0.885132          -0.453029
# petal width in cm  -0.117532            0.815522          -0.400215
# class               0.111360           -0.399178          -0.079303
#
#                     petal length in cm  petal width in cm     class
# id                           -0.146934          -0.117532  0.111360
# sepal length in cm            0.885132           0.815522 -0.399178
# sepal width in cm            -0.453029          -0.400215 -0.079303
# petal length in cm            1.000000           0.955735 -0.385409
# petal width in cm             0.955735           1.000000 -0.426145
# class                        -0.385409          -0.426145  1.000000

# %%
# 相関がありそうなのはpetal length in cm, sepal length in cm, petal width in cm

# %%
# 今回はsepal width in cmも追加してみる
trainX = df_train2[['sepal length in cm', 'petal length in cm', 'petal width in cm', 'sepal width in cm']]

# %%
test_y = df_train2['class']

# %%
# モデルの宣言
model = RandomForestClassifier(n_estimators = 80, random_state=0)

# %%
# モデルの学習
model.fit(trainX, test_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=80, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
testX = df_test[['sepal length in cm', 'petal length in cm', 'petal width in cm', 'sepal width in cm']]

# %%
test_y = model.predict(testX)

# %%
output = pd.read_csv('test.csv', sep='\t')

# %%
output['class'] = test_y

# %%
# test_yの数値の置き換えをアヤメの品種に変換しなおす必要あり
# まずは適当な変数に変換したい数値を代入
output_temp = output['class']

# %%
# 確認
output_temp
# Out:
# 0     2
# 1     2
# 2     0
# 3     2
# 4     1
# 5     1
# 6     0
# 7     2
# 8     1
# 9     0
# 10    2
# 11    1
# 12    1
# 13    0
# 14    2
# 15    0
# 16    0
# 17    0
# 18    0
# 19    2
# 20    0
# 21    1
# 22    2
# 23    1
# 24    1
# 25    2
# 26    2
# 27    0
# 28    1
# 29    1
#      ..
# 45    2
# 46    1
# 47    1
# 48    2
# 49    2
# 50    0
# 51    2
# 52    0
# 53    0
# 54    2
# 55    2
# 56    0
# 57    2
# 58    0
# 59    0
# 60    2
# 61    2
# 62    1
# 63    1
# 64    1
# 65    0
# 66    0
# 67    1
# 68    2
# 69    1
# 70    2
# 71    1
# 72    2
# 73    0
# 74    1
# Name: class, Length: 75, dtype: int64

# %%
# 数値を元のアヤメの品種名に変換
output_class = output_temp.replace(0, 'Iris-virginica').replace(1, 'Iris-setosa').replace(2, 'Iris-versicolor')

# %%
# 品種名に変換できているか確認
output_class
# Out:
# 0     Iris-versicolor
# 1     Iris-versicolor
# 2      Iris-virginica
# 3     Iris-versicolor
# 4         Iris-setosa
# 5         Iris-setosa
# 6      Iris-virginica
# 7     Iris-versicolor
# 8         Iris-setosa
# 9      Iris-virginica
# 10    Iris-versicolor
# 11        Iris-setosa
# 12        Iris-setosa
# 13     Iris-virginica
# 14    Iris-versicolor
# 15     Iris-virginica
# 16     Iris-virginica
# 17     Iris-virginica
# 18     Iris-virginica
# 19    Iris-versicolor
# 20     Iris-virginica
# 21        Iris-setosa
# 22    Iris-versicolor
# 23        Iris-setosa
# 24        Iris-setosa
# 25    Iris-versicolor
# 26    Iris-versicolor
# 27     Iris-virginica
# 28        Iris-setosa
# 29        Iris-setosa
#            ...
# 45    Iris-versicolor
# 46        Iris-setosa
# 47        Iris-setosa
# 48    Iris-versicolor
# 49    Iris-versicolor
# 50     Iris-virginica
# 51    Iris-versicolor
# 52     Iris-virginica
# 53     Iris-virginica
# 54    Iris-versicolor
# 55    Iris-versicolor
# 56     Iris-virginica
# 57    Iris-versicolor
# 58     Iris-virginica
# 59     Iris-virginica
# 60    Iris-versicolor
# 61    Iris-versicolor
# 62        Iris-setosa
# 63        Iris-setosa
# 64        Iris-setosa
# 65     Iris-virginica
# 66     Iris-virginica
# 67        Iris-setosa
# 68    Iris-versicolor
# 69        Iris-setosa
# 70    Iris-versicolor
# 71        Iris-setosa
# 72    Iris-versicolor
# 73     Iris-virginica
# 74        Iris-setosa
# Name: class, Length: 75, dtype: object

# %%
# 変換したものを[class]カラムに格納
output['class'] = output_class

# %%
# [class]カラムに格納できているか確認
output
# Out:
#      id  sepal length in cm  sepal width in cm  petal length in cm  \
# 0     2                 6.1                2.8                 4.7
# 1     7                 6.3                2.5                 4.9
# 2     8                 6.2                3.4                 5.4
# 3    10                 6.7                3.1                 4.7
# 4    13                 5.0                3.4                 1.6
# 5    15                 4.4                3.0                 1.3
# 6    16                 6.3                2.9                 5.6
# 7    18                 7.0                3.2                 4.7
# 8    20                 4.9                3.0                 1.4
# 9    22                 6.7                3.3                 5.7
# 10   24                 5.4                3.0                 4.5
# 11   26                 5.4                3.4                 1.5
# 12   27                 5.1                3.5                 1.4
# 13   30                 7.7                3.0                 6.1
# 14   33                 6.7                3.1                 4.4
# 15   37                 6.8                3.2                 5.9
# 16   40                 6.0                2.7                 5.1
# 17   43                 6.8                3.0                 5.5
# 18   44                 5.7                2.5                 5.0
# 19   45                 6.0                2.9                 4.5
# 20   48                 5.8                2.7                 5.1
# 21   50                 5.0                3.3                 1.4
# 22   51                 5.0                2.3                 3.3
# 23   52                 4.8                3.4                 1.6
# 24   54                 4.6                3.1                 1.5
# 25   56                 5.5                2.5                 4.0
# 26   59                 5.7                2.8                 4.1
# 27   60                 7.4                2.8                 6.1
# 28   61                 5.2                3.4                 1.4
# 29   62                 4.8                3.4                 1.9
# ..  ...                 ...                ...                 ...
# 45   91                 5.6                3.0                 4.5
# 46   92                 5.0                3.5                 1.3
# 47   93                 4.4                2.9                 1.4
# 48   94                 6.0                2.2                 4.0
# 49   95                 4.9                2.4                 3.3
# 50   97                 5.8                2.7                 5.1
# 51  100                 6.5                2.8                 4.6
# 52  101                 6.4                2.8                 5.6
# 53  106                 6.9                3.1                 5.4
# 54  107                 5.1                2.5                 3.0
# 55  108                 5.7                2.8                 4.5
# 56  111                 6.3                2.8                 5.1
# 57  112                 6.4                2.9                 4.3
# 58  114                 6.9                3.2                 5.7
# 59  116                 6.3                2.5                 5.0
# 60  119                 6.2                2.9                 4.3
# 61  121                 5.7                3.0                 4.2
# 62  123                 5.1                3.3                 1.7
# 63  125                 4.3                3.0                 1.1
# 64  126                 4.6                3.4                 1.4
# 65  127                 6.3                3.3                 6.0
# 66  132                 6.7                3.0                 5.0
# 67  133                 5.1                3.8                 1.5
# 68  134                 5.5                2.4                 3.8
# 69  135                 5.4                3.4                 1.7
# 70  137                 5.8                2.6                 4.0
# 71  141                 5.1                3.5                 1.4
# 72  144                 6.2                2.2                 4.5
# 73  146                 6.5                3.0                 5.2
# 74  147                 5.2                3.5                 1.5
#
#     petal width in cm            class
# 0                 1.2  Iris-versicolor
# 1                 1.5  Iris-versicolor
# 2                 2.3   Iris-virginica
# 3                 1.5  Iris-versicolor
# 4                 0.4      Iris-setosa
# 5                 0.2      Iris-setosa
# 6                 1.8   Iris-virginica
# 7                 1.4  Iris-versicolor
# 8                 0.2      Iris-setosa
# 9                 2.5   Iris-virginica
# 10                1.5  Iris-versicolor
# 11                0.4      Iris-setosa
# 12                0.3      Iris-setosa
# 13                2.3   Iris-virginica
# 14                1.4  Iris-versicolor
# 15                2.3   Iris-virginica
# 16                1.6   Iris-virginica
# 17                2.1   Iris-virginica
# 18                2.0   Iris-virginica
# 19                1.5  Iris-versicolor
# 20                1.9   Iris-virginica
# 21                0.2      Iris-setosa
# 22                1.0  Iris-versicolor
# 23                0.2      Iris-setosa
# 24                0.2      Iris-setosa
# 25                1.3  Iris-versicolor
# 26                1.3  Iris-versicolor
# 27                1.9   Iris-virginica
# 28                0.2      Iris-setosa
# 29                0.2      Iris-setosa
# ..                ...              ...
# 45                1.5  Iris-versicolor
# 46                0.3      Iris-setosa
# 47                0.2      Iris-setosa
# 48                1.0  Iris-versicolor
# 49                1.0  Iris-versicolor
# 50                1.9   Iris-virginica
# 51                1.5  Iris-versicolor
# 52                2.2   Iris-virginica
# 53                2.1   Iris-virginica
# 54                1.1  Iris-versicolor
# 55                1.3  Iris-versicolor
# 56                1.5   Iris-virginica
# 57                1.3  Iris-versicolor
# 58                2.3   Iris-virginica
# 59                1.9   Iris-virginica
# 60                1.3  Iris-versicolor
# 61                1.2  Iris-versicolor
# 62                0.5      Iris-setosa
# 63                0.1      Iris-setosa
# 64                0.3      Iris-setosa
# 65                2.5   Iris-virginica
# 66                1.7   Iris-virginica
# 67                0.3      Iris-setosa
# 68                1.1  Iris-versicolor
# 69                0.2      Iris-setosa
# 70                1.2  Iris-versicolor
# 71                0.2      Iris-setosa
# 72                1.5  Iris-versicolor
# 73                2.0   Iris-virginica
# 74                0.2      Iris-setosa
#
# [75 rows x 6 columns]

# %%
output[['id', 'class']].to_csv('submission1.csv', header=False, index=False)

# %%
# Accuracy=0.0.9733333333333334で1回目よりアップ
